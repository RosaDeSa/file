# %% [markdown]
# <a href="https://colab.research.google.com/github/RosaDeSa/file/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # Library for Dataframe handling
from sklearn.preprocessing import LabelEncoder # sklear = ML Library
import json # Manage Text data
import folktables # Not in google colab; to use it we have to install it in cloud
# To 
import numpy as np # Numeric values management
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e7546157646e> in <cell line: 4>()
#       2 from sklearn.preprocessing import LabelEncoder # sklear = ML Library
#       3 import json # Manage Text data
# ----> 4 import folktables # Not in google colab; to use it we have to install it in cloud
#       5 # To
#       6 import numpy as np # Numeric values management
#
# ModuleNotFoundError: No module named 'folktables'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip3 install folktables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
continous_feature_L = [
    "hours-per-week",
    "age",
    "capital-gain",
    "capital-loss",
    "education-num",
]

categorical_feature_L = [
    "workclass",
    "education",
    "marital-status",
    "relationship",
    "race",
    "gender",
    "native-country",
    "occupation",
]

url = 'https://raw.githubusercontent.com/socialfoundations/folktables/main/adult_reconstruction.csv'
df1 = pd.read_csv(url)# Dataset is now stored in a Pandas Dataframe

df1.head()
# Out:
#    hours-per-week  age  capital-gain  capital-loss workclass     education  \
# 0              20   40             0             0   Private     Bachelors
# 1              40   21             0             0   Private  Some-college
# 2              10   17             0             0   Private          11th
# 3              50   51             0             0   Private       HS-grad
# 4              38   28             0             0   Private     Bachelors
#
#    education-num      marital-status   relationship                race  \
# 0             13  Married-civ-spouse           Wife               White
# 1             10            Divorced      Own-child               White
# 2              7       Never-married      Own-child               White
# 3              9  Married-civ-spouse        Husband  Asian-Pac-Islander
# 4             13       Never-married  Not-in-family               White
#
#    gender native-country  income       occupation
# ...
